# %% [markdown]
# ![Demosaicking](https://raw.githubusercontent.com/semilleroCV/Hands-on-Computer-Vision/0129bbd70539e5c601b76b03e4d3883f67c39e72/Sesiones/Sesion2/Images/poster_sesion2.png)

# %% [markdown]
# # 🎨 **Hands-on Sesión 2.2: Image Processing Pipeline** 🖼️
#
# En esta sesión aprenderemos a aplicar distintas transformaciones en imágenes RAW como parte de un **pipeline de procesamiento de imágenes**. 🚀
#
# Exploraremos:
# ✅ Carga y visualización de imágenes RAW 📷
# ✅ Corrección de ruido 🧹
# ✅ Ajuste de brillo y color 🌈
# ✅ Corrección gamma ⚡
# ✅ Cambio de espacio de color 🎭
# ✅ Demosaicking avanzado con el método AHD 🏞️
#
#
# ## 📂 **1. Cargar librerías** <a name="tema1"></a>

# %% [markdown]
# Vamos a instalar y cargar las librerías necesarias para procesar imágenes RAW.

# %%
# %%capture
# !pip install -q rawpy
import numpy as np
import matplotlib.pyplot as plt
import rawpy

# %% [markdown]
# ## 📥 **2. Cargar una imagen RAW** <a name="tema2"></a>

# %% [markdown]
# Descarguemos y carguemos una imagen de ejemplo en formato `.dng` para trabajar en esta sesión.

# %%
# @title Descargar imagen
# %%capture
image_dir = "raw_GOPRO1.dng"
# !wget https://raw.githubusercontent.com/cvail-research/backup_-Hands-on-Computer-Vision-Public/refs/heads/2024/Sesiones/Sesion2/Imagenes/raw_GOPRO1.dng

# %% [markdown]
# ### 🔍 **Metadatos de la imagen RAW**
#
# Para entender mejor la imagen, vamos a inspeccionar sus metadatos usando `exiftool`.

# %%
# !apt-get install exiftool -y -qq
# !exiftool raw_GOPRO1.dng
# Out:
# Selecting previously unselected package libarchive-zip-perl.
# (Reading database ... 118194 files and directories currently installed.)
# Preparing to unpack .../libarchive-zip-perl_1.68-1_all.deb ...
# Unpacking libarchive-zip-perl (1.68-1) ...
# Selecting previously unselected package libimage-exiftool-perl.
# Preparing to unpack .../libimage-exiftool-perl_12.40+dfsg-1_all.deb ...
# Unpacking libimage-exiftool-perl (12.40+dfsg-1) ...
# Selecting previously unselected package libmime-charset-perl.
# Preparing to unpack .../libmime-charset-perl_1.012.2-1_all.deb ...
# Unpacking libmime-charset-perl (1.012.2-1) ...
# Selecting previously unselected package libsombok3:amd64.
# Preparing to unpack .../libsombok3_2.4.0-2_amd64.deb ...
# Unpacking libsombok3:amd64 (2.4.0-2) ...
# Selecting previously unselected package libunicode-linebreak-perl.
# Preparing to unpack .../libunicode-linebreak-perl_0.0.20190101-1build3_amd64.deb ...
# Unpacking libunicode-linebreak-perl (0.0.20190101-1build3) ...
# Setting up libsombok3:amd64 (2.4.0-2) ...
# Setting up libarchive-zip-perl (1.68-1) ...
# Setting up libimage-exiftool-perl (12.40+dfsg-1) ...
# Setting up libmime-charset-perl (1.012.2-1) ...
# Setting up libunicode-linebreak-perl (0.0.20190101-1build3) ...
# Processing triggers for man-db (2.10.2-1) ...
# Processing triggers for libc-bin (2.35-0ubuntu3.13) ...
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_opencl.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_0.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libumf.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbbind_2_5.so.3 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbb.so.12 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtbbmalloc_proxy.so.2 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm_debug.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero_v2.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libtcm.so.1 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libhwloc.so.15 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_adapter_level_zero.so.0 is not a symbolic link
#
# /sbin/ldconfig.real: /usr/local/lib/libur_loader.so.0 is not a symbolic link
#
# ExifTool Version Number         : 12.40
# File Name                       : raw_GOPRO1.dng
# Directory                       : .
# File Size                       : 14 MiB
# File Modification Date/Time     : 2026:04:20 21:56:43+00:00
# File Access Date/Time           : 2026:04:20 21:56:50+00:00
# File Inode Change Date/Time     : 2026:04:20 21:56:43+00:00
# File Permissions                : -rw-r--r--
# File Type                       : DNG
# File Type Extension             : dng
# MIME Type                       : image/x-adobe-dng
# Exif Byte Order                 : Little-endian (Intel, II)
# Image Description               : C:\DCIM\100GOPRO\GOPR0401.GPR
# Make                            : GoPro
# Camera Model Name               : HERO8 Black
# Strip Offsets                   : 20674
# Orientation                     : Mirror horizontal
# Rows Per Strip                  : 192
# Strip Byte Counts               : 147456
# Software                        : Adobe DNG Converter 16.2 (Windows)
# Modify Date                     : 2024:03:10 21:20:23
# Image Width                     : 4000
# Image Height                    : 3000
# Bits Per Sample                 : 16
# Compression                     : JPEG
# Photometric Interpretation      : Color Filter Array
# Samples Per Pixel               : 1
# Planar Configuration            : Chunky
# CFA Repeat Pattern Dim          : 2 2
# CFA Pattern 2                   : 0 1 1 2
# CFA Plane Color                 : Red,Green,Blue
# CFA Layout                      : Rectangular
# Black Level Repeat Dim          : 2 2
# White Level                     : 16383
# Default Scale                   : 1 1
# Default Crop Origin             : 0 0
# Default Crop Size               : 4000 3000
# Bayer Green Split               : 0
# Anti Alias Strength             : 1
# Best Quality Scale              : 1
# Active Area                     : 0 0 3000 4000
# Preview Image Start             : 168130
# Preview Image Length            : 56697
# Y Cb Cr Coefficients            : 0.299 0.587 0.114
# Y Cb Cr Sub Sampling            : YCbCr4:2:0 (2 2)
# Y Cb Cr Positioning             : Unknown (0)
# Reference Black White           : 0 255 128 255 128 255
# Subfile Type                    : Reduced-resolution image
# Tile Width                      : 256
# Tile Length                     : 192
# Tile Offsets                    : 679758
# Tile Byte Counts                : 9419
# Black Level                     : 8525 9307 9074
# Opcode List 2                   : MapPolynomial, MapPolynomial, MapPolynomial
# Cache Version                   : 0.1.0.0
# XMP Toolkit                     : Adobe XMP Core 7.0-c000 1.000000, 0000/00/00-00:00:00
# Creator Tool                    : Adobe DNG Converter 16.2 (Windows)
# Metadata Date                   : 2024:03:10 21:20:23-05:00
# Format                          : image/dng
# Date Created                    : 2024:03:09 11:31:42
# Document ID                     : xmp.did:b33e4ac3-80b7-5243-aa60-6a0ac97395df
# Original Document ID            : 306B581BB2AFB4A4F9D1A65901D7B7C2
# Instance ID                     : xmp.iid:b33e4ac3-80b7-5243-aa60-6a0ac97395df
# Has Settings                    : False
# Has Crop                        : False
# Already Applied                 : False
# Description                     : C:\DCIM\100GOPRO\GOPR0401.GPR
# History Action                  : derived, saved
# History Parameters              : saved to new location
# History Instance ID             : xmp.iid:b33e4ac3-80b7-5243-aa60-6a0ac97395df
# History When                    : 2024:03:10 21:20:23-05:00
# History Software Agent          : Adobe DNG Converter 16.2 (Windows)
# History Changed                 : /
# Derived From Document ID        : 306B581BB2AFB4A4F9D1A65901D7B7C2
# Derived From Original Document ID: 306B581BB2AFB4A4F9D1A65901D7B7C2
# Exposure Time                   : 1/120
# F Number                        : 2.8
# Exposure Program                : Program AE
# ISO                             : 520
# Exif Version                    : 0231
# Date/Time Original              : 2024:03:09 11:31:42
# Create Date                     : 2016:03:25 15:55:23
# Offset Time                     : -05:00
# Shutter Speed Value             : 1/120
# Aperture Value                  : 2.8
# Exposure Compensation           : 0
# Max Aperture Value              : 2.8
# Metering Mode                   : Average
# Light Source                    : Unknown
# Flash                           : No flash function
# Focal Length                    : 3.0 mm
# Focal Plane X Resolution        : 72
# Focal Plane Y Resolution        : 72
# Sensing Method                  : One-chip color area
# File Source                     : Digital Camera
# Scene Type                      : Directly photographed
# Exposure Mode                   : Auto
# White Balance                   : Auto
# Digital Zoom Ratio              : 1
# Focal Length In 35mm Format     : 15 mm
# Scene Capture Type              : Landscape
# Gain Control                    : None
# Contrast                        : Normal
# Saturation                      : Normal
# Sharpness                       : Hard
# Serial Number                   : C3334252791908
# GPS Version ID                  : 2.2.0.0
# GPS Latitude Ref                : North
# GPS Longitude Ref               : West
# GPS Altitude Ref                : Above Sea Level
# GPS Differential                : No Correction
# DNG Version                     : 1.7.0.0
# DNG Backward Version            : 1.1.0.0
# Unique Camera Model             : GoPro HERO8 Black
# Localized Camera Model          : GoPro HERO8 Black
# Color Matrix 1                  : 1.8331 -0.8166 -0.2478 0.1391 0.8961 -0.0367 0.0822 0.0662 0.2597
# Color Matrix 2                  : 1.0344 -0.421 -0.062 -0.2315 1.0625 0.1948 0.0093 0.1058 0.5541
# Analog Balance                  : 1 1 1
# As Shot Neutral                 : 0.573991 1 0.412903
# Baseline Exposure               : 0
# Baseline Noise                  : 1
# Baseline Sharpness              : 1
# Linear Response Limit           : 1
# Camera Serial Number            : C3334252791908
# Shadow Scale                    : 1
# Calibration Illuminant 1        : Tungsten (Incandescent)
# Calibration Illuminant 2        : D50
# Raw Data Unique ID              : 25C692C9B4C8D9C725577CE69FAF10A6
# Original Raw File Name          : RAW FILE
# Profile Name                    : GoPro HERO8 Black
# Profile Embed Policy            : Allow Copying
# Preview Application Name        : Adobe DNG Converter
# Preview Application Version     : 16.2
# Preview Settings Digest         : add84408abb19b36964d47cf547fcf0d
# Preview Color Space             : sRGB
# Preview Date Time               : 2024:03:10 21:20:19-05:00
# Noise Profile                   : 0.000812241400126368 2.53760987334317e-07
# New Raw Image Digest            : 109ad0a17b255df08c9092ebaed0bfac
# Aperture                        : 2.8
# CFA Pattern                     : [Red,Green][Green,Blue]
# Image Size                      : 4000x3000
# Megapixels                      : 12.0
# Preview Image                   : (Binary data 56697 bytes, use -b option to extract)
# Scale Factor To 35 mm Equivalent: 5.0
# Shutter Speed                   : 1/120
# Modify Date                     : 2024:03:10 21:20:23-05:00
# Thumbnail TIFF                  : (Binary data 147672 bytes, use -b option to extract)
# GPS Altitude                    : 1013.5 m Above Sea Level
# GPS Latitude                    : 7 deg 8' 28.28" N
# GPS Longitude                   : 73 deg 7' 22.74" W
# Circle Of Confusion             : 0.006 mm
# Field Of View                   : 100.4 deg
# Focal Length                    : 3.0 mm (35 mm equivalent: 15.0 mm)
# GPS Position                    : 7 deg 8' 28.28" N, 73 deg 7' 22.74" W
# Hyperfocal Distance             : 0.53 m
# Light Value                     : 7.5

# %% [markdown]
# ### 🖼️ **Visualización de la imagen RAW**

# %%
with rawpy.imread(image_dir) as raw:
    image0 = raw.raw_image_visible.copy()
plt.imshow(image0, cmap='gray')
plt.colorbar()
plt.title("Imagen RAW Original")
plt.show()

# %% [markdown]
# ## 🧹 **3. Corrección de ruido previa a la convolución** <a name="tema3"></a>
#
# Aplicamos reducción de ruido utilizando **Filtro de Detección de Bordes Bilateral** (FBDD).

# %%
with rawpy.imread(image_dir) as raw:
    image1 = raw.postprocess(
        fbdd_noise_reduction=rawpy.FBDDNoiseReductionMode(1),
        demosaic_algorithm=rawpy.DemosaicAlgorithm(0),
        output_color=rawpy.ColorSpace(1),
        no_auto_scale=True,
        no_auto_bright=True,
        gamma=(1,1)
    )
plt.imshow(image1)
plt.colorbar()
plt.title("Corrección de Ruido")
plt.show()

# %% [markdown]
# ## 🎨 **4. Corrección de Color** <a name="tema4"></a>
#
# Eliminamos `no_auto_scale` para permitir la corrección automática de color.

# %%
with rawpy.imread(image_dir) as raw:
    image2 = raw.postprocess(
        fbdd_noise_reduction=rawpy.FBDDNoiseReductionMode(1),
        demosaic_algorithm=rawpy.DemosaicAlgorithm(0),
        output_color=rawpy.ColorSpace(1),
        no_auto_scale=False,
        no_auto_bright=True,
        gamma=(1,1)
    )
plt.imshow(image2)
plt.colorbar()
plt.title("Corrección de Color")
plt.show()

# %% [markdown]
# ## 🔆 **5. Ajuste de Brillo** <a name="tema5"></a>
#
# Eliminamos `no_auto_bright` para permitir ajuste automático del brillo.

# %%
with rawpy.imread(image_dir) as raw:
    image3 = raw.postprocess(
        fbdd_noise_reduction=rawpy.FBDDNoiseReductionMode(2),
        demosaic_algorithm=rawpy.DemosaicAlgorithm(4),
        output_color=rawpy.ColorSpace(3),
        no_auto_scale=False,
        no_auto_bright=False,
        gamma=(1,.2)
    )
plt.imshow(image3)
plt.colorbar()
plt.title("Ajuste de Brillo")
plt.show()

# %% [markdown]
# ## ⚡ **6. Corrección Gamma** <a name="tema6"></a>

# %%
with rawpy.imread(image_dir) as raw:
    image4 = raw.postprocess(
        fbdd_noise_reduction=rawpy.FBDDNoiseReductionMode(1),
        demosaic_algorithm=rawpy.DemosaicAlgorithm(0),
        output_color=rawpy.ColorSpace(1),
        no_auto_scale=False,
        no_auto_bright=False,
        gamma=(2.222, 4.5)
    )
plt.imshow(image4)
plt.colorbar()
plt.title("Corrección Gamma")
plt.show()

# %% [markdown]
# ## 🌍 **7. Cambio de Espacio de Color a P3D65** <a name="tema7"></a>

# %%
with rawpy.imread(image_dir) as raw:
    image5 = raw.postprocess(
        fbdd_noise_reduction=rawpy.FBDDNoiseReductionMode(1),
        demosaic_algorithm=rawpy.DemosaicAlgorithm(0),
        output_color=rawpy.ColorSpace(7),
        no_auto_scale=False,
        no_auto_bright=False,
        gamma=(2.222, 4.5)
    )
plt.imshow(image5)
plt.colorbar()
plt.title("Espacio de Color P3D65")
plt.show()

# %% [markdown]
# ## 🏞️ **8. Demosaicking con AHD** <a name="tema8"></a>

# %%
with rawpy.imread(image_dir) as raw:
    image6 = raw.postprocess(
        fbdd_noise_reduction=rawpy.FBDDNoiseReductionMode(1),
        demosaic_algorithm=rawpy.DemosaicAlgorithm(3),
        output_color=rawpy.ColorSpace(7),
        no_auto_scale=True,
        no_auto_bright=False,
        gamma=(2.222, 4.5)
    )
plt.imshow(image6)
plt.colorbar()
plt.title("Demosaicking AHD")
plt.show()

# %%
# overview all images
fig, axs = plt.subplots(2, 3, figsize=(20, 10))
axs[0, 0].imshow(image1)
axs[0, 0].set_title("Corrección de Ruido")
axs[0, 1].imshow(image2)
axs[0, 1].set_title("Corrección de Color")
axs[0, 2].imshow(image3)
axs[0, 2].set_title("Ajuste de Brillo")
axs[1, 0].imshow(image4)
axs[1, 0].set_title("Corrección Gamma")
axs[1, 1].imshow(image5)
axs[1, 1].set_title("Espacio de Color P3D65")
axs[1, 2].imshow(image6)
axs[1, 2].set_title("Demosaicking AHD")
for ax in axs.flat:
    ax.label_outer()
plt.show()
